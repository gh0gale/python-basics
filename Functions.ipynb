# %%
def multiply(x,y):
    return x*y
multiply(3,4)
# Out:
# 12

# %%
def is_even(n):
    if n%2==0:
        return print(True)
    else:
        return print(False)
 
n = int(input("enter the number"))
is_even(n)
# Out:
# False

# %%
def concat(a,b):
    return print(a + " " + b)
x = "hello"
y = "world"
concat(x,y)
# Out:
# hello world

# %%
d1 = {}
